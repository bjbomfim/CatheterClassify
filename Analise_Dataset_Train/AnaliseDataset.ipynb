# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
# Out:
# /Users/alexandrebomfim/opt/anaconda3/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
raio_x_invasive_proce  = pd.read_csv('../Dataset/train.csv')

# %%
raio_x_invasive_proce.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30083 entries, 0 to 30082
# Data columns (total 13 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   StudyInstanceUID            30083 non-null  object
#  1   ETT - Abnormal              30083 non-null  int64
#  2   ETT - Borderline            30083 non-null  int64
#  3   ETT - Normal                30083 non-null  int64
#  4   NGT - Abnormal              30083 non-null  int64
#  5   NGT - Borderline            30083 non-null  int64
#  6   NGT - Incompletely Imaged   30083 non-null  int64
#  7   NGT - Normal                30083 non-null  int64
#  8   CVC - Abnormal              30083 non-null  int64
#  9   CVC - Borderline            30083 non-null  int64
#  10  CVC - Normal                30083 non-null  int64
#  11  Swan Ganz Catheter Present  30083 non-null  int64
#  12  PatientID                   30083 non-null  object
# ...

# %%
ett = ['ETT - Abnormal', 'ETT - Borderline', 'ETT - Normal']
ngt = ['NGT - Abnormal', 'NGT - Borderline', 'NGT - Incompletely Imaged', 'NGT - Normal']
cvc = ['CVC - Abnormal', 'CVC - Borderline', 'CVC - Normal']

# %%
plt.hist(x = raio_x_invasive_proce[ett].where(raio_x_invasive_proce[ett] == 1), label=ett);

plt.legend(loc='upper right')

plt.title('Histograma de Tubo Endotraqueal')
plt.ylabel('Frequência')
plt.show();

# %%
plt.hist(x = raio_x_invasive_proce[ngt].where(raio_x_invasive_proce[ngt] == 1), label=ngt);

plt.legend(loc='upper right')

plt.title('Histograma de Sonda Nasogástrica')
plt.ylabel('Frequência')
plt.show();

# %%
plt.hist(x = raio_x_invasive_proce[cvc].where(raio_x_invasive_proce[cvc] == 1), label=cvc);

plt.legend(loc='upper right')

plt.title('Histograma de Cateter Venoso Central')
plt.ylabel('Frequência')
plt.show();

# %%
plt.hist(x = raio_x_invasive_proce['Swan Ganz Catheter Present'].where(raio_x_invasive_proce['Swan Ganz Catheter Present'] == 1), label='Swan Ganz Catheter Present');

plt.legend(loc='upper right')

plt.title('Histograma de Cateter Venoso Central')
plt.ylabel('Frequência')
plt.show();

# %%
raio_x_invasive_proce.where(raio_x_invasive_proce == 1).count()
# Out:
# StudyInstanceUID                  0
# ETT - Abnormal                   79
# ETT - Borderline               1138
# ETT - Normal                   7240
# NGT - Abnormal                  279
# NGT - Borderline                529
# NGT - Incompletely Imaged      2748
# NGT - Normal                   4797
# CVC - Abnormal                 3195
# CVC - Borderline               8460
# CVC - Normal                  21324
# Swan Ganz Catheter Present      830
# PatientID                         0
# dtype: int64

# %%
porcent = np.divide(raio_x_invasive_proce.where(raio_x_invasive_proce == 1).count(), np.sum(raio_x_invasive_proce.where(raio_x_invasive_proce == 1 ).count()))

listas = [ett, ngt, cvc]
x = []
for lista in listas:
    
    x.extend(lista)

# %%
    
x.append("Swan Ganz Catheter Present")
plt.figure(figsize=(10, 6))
plt.barh(x, porcent[x]*100, color=['skyblue', 'skyblue', 'skyblue',  'lightgreen',  'lightgreen',  'lightgreen',  'lightgreen',  'gold', 'gold', 'gold', 'lightcoral',])

plt.xlabel('Porcentagem')
plt.title('Gráfico dos Grupos')

plt.show()

# %%
porcent = np.divide(raio_x_invasive_proce.where(raio_x_invasive_proce[ett] == 1).count(), np.sum(raio_x_invasive_proce.where(raio_x_invasive_proce[ett] == 1 ).count()))
porcent_ett = porcent[ett]

plt.figure(figsize=(10, 6))
plt.barh(ett, porcent_ett*100)

plt.xlabel('Porcentagem')
plt.title('Gráfico do Grupo ETT')

plt.show()

# %%
porcent = np.divide(raio_x_invasive_proce.where(raio_x_invasive_proce[ngt] == 1).count(), np.sum(raio_x_invasive_proce.where(raio_x_invasive_proce[ngt] == 1 ).count()))
porcent_ngt = porcent[ngt]

plt.figure(figsize=(10, 6))
plt.barh(ngt, porcent_ngt*100)

plt.xlabel('Porcentagem')
plt.title('Gráfico do Grupo NGT')

plt.show()

# %%
porcent = np.divide(raio_x_invasive_proce.where(raio_x_invasive_proce[cvc] == 1).count(), np.sum(raio_x_invasive_proce.where(raio_x_invasive_proce[cvc] == 1 ).count()))
porcent_cvc = porcent[cvc]

plt.figure(figsize=(10, 6))
plt.barh(cvc, porcent_cvc*100)

plt.xlabel('Porcentagem')
plt.title('Gráfico do Grupo cvc')

plt.show()

# %%
more_one = raio_x_invasive_proce[(raio_x_invasive_proce == 1).sum(axis=1) > 1]

more_one.head()
# Out:
#                                     StudyInstanceUID  ETT - Abnormal  \
# 1  1.2.826.0.1.3680043.8.498.46302891597398758759...               0
# 5  1.2.826.0.1.3680043.8.498.11707076266253086830...               0
# 6  1.2.826.0.1.3680043.8.498.23133310896792275593...               0
# 7  1.2.826.0.1.3680043.8.498.17332833449968516367...               0
# 8  1.2.826.0.1.3680043.8.498.91266853519846682206...               0
#
#    ETT - Borderline  ETT - Normal  NGT - Abnormal  NGT - Borderline  \
# 1                 0             1               0                 0
# 5                 0             1               0                 0
# 6                 0             0               0                 0
# 7                 0             1               0                 0
# 8                 0             0               0                 0
#
#    NGT - Incompletely Imaged  NGT - Normal  CVC - Abnormal  CVC - Borderline  \
# ...

# %%
more_one.count()
plt.figure(figsize=(10, 6))
plt.barh(['Apenas uma etiqueta', 'Mais de uma etiqueta'],[len(more_one), 18_784])

plt.xlabel('Frequencia')
plt.title('Gráfico de Etiquetas')

plt.show()

# %%
more_two = raio_x_invasive_proce[(raio_x_invasive_proce == 1).sum(axis=1) == 2]
more_two.where(more_two == 1).count()
more_two.count()
# Out:
# StudyInstanceUID              4338
# ETT - Abnormal                4338
# ETT - Borderline              4338
# ETT - Normal                  4338
# NGT - Abnormal                4338
# NGT - Borderline              4338
# NGT - Incompletely Imaged     4338
# NGT - Normal                  4338
# CVC - Abnormal                4338
# CVC - Borderline              4338
# CVC - Normal                  4338
# Swan Ganz Catheter Present    4338
# PatientID                     4338
# dtype: int64

# %%
more_three = raio_x_invasive_proce[(raio_x_invasive_proce == 1).sum(axis=1) == 3]
more_three.where(more_three == 1).count()
# Out:
# StudyInstanceUID                 0
# ETT - Abnormal                  36
# ETT - Borderline               623
# ETT - Normal                  3834
# NGT - Abnormal                 122
# NGT - Borderline               274
# NGT - Incompletely Imaged     1569
# NGT - Normal                  2593
# CVC - Abnormal                 474
# CVC - Borderline              1375
# CVC - Normal                  3570
# Swan Ganz Catheter Present     101
# PatientID                        0
# dtype: int64

# %%
more_four = raio_x_invasive_proce[(raio_x_invasive_proce == 1).sum(axis=1) == 4]
more_four.count()
more_four.where(more_four == 1).count()
# Out:
# StudyInstanceUID                 0
# ETT - Abnormal                  15
# ETT - Borderline               271
# ETT - Normal                  1617
# NGT - Abnormal                  52
# NGT - Borderline                86
# NGT - Incompletely Imaged      723
# NGT - Normal                  1055
# CVC - Abnormal                 394
# CVC - Borderline              1202
# CVC - Normal                  1761
# Swan Ganz Catheter Present     488
# PatientID                        0
# dtype: int64

# %%
more_five = raio_x_invasive_proce[(raio_x_invasive_proce == 1).sum(axis=1) == 5]
more_five.count()
more_five.where(more_five == 1).count()
# Out:
# StudyInstanceUID                0
# ETT - Abnormal                  0
# ETT - Borderline               26
# ETT - Normal                  154
# NGT - Abnormal                  8
# NGT - Borderline               11
# NGT - Incompletely Imaged      69
# NGT - Normal                  102
# CVC - Abnormal                 52
# CVC - Borderline              162
# CVC - Normal                  179
# Swan Ganz Catheter Present    137
# PatientID                       0
# dtype: int64

# %%
equal_six = raio_x_invasive_proce[(raio_x_invasive_proce == 1).sum(axis=1) == 6]
equal_six.count()
equal_six.where(equal_six == 1).count()
# Out:
# StudyInstanceUID              0
# ETT - Abnormal                0
# ETT - Borderline              3
# ETT - Normal                  5
# NGT - Abnormal                0
# NGT - Borderline              0
# NGT - Incompletely Imaged     5
# NGT - Normal                  3
# CVC - Abnormal                8
# CVC - Borderline              8
# CVC - Normal                  8
# Swan Ganz Catheter Present    8
# PatientID                     0
# dtype: int64

# %%
more_five
# Out:
#                                         StudyInstanceUID  ETT - Abnormal  \
# 182    1.2.826.0.1.3680043.8.498.30375942591308414021...               0
# 262    1.2.826.0.1.3680043.8.498.12011647071471951833...               0
# 354    1.2.826.0.1.3680043.8.498.61509667175733079186...               0
# 383    1.2.826.0.1.3680043.8.498.56254514291554823758...               0
# 649    1.2.826.0.1.3680043.8.498.92806175825736916132...               0
# ...                                                  ...             ...
# 29545  1.2.826.0.1.3680043.8.498.89523395356572231919...               0
# 29665  1.2.826.0.1.3680043.8.498.12342227351706624717...               0
# 29680  1.2.826.0.1.3680043.8.498.11931339765295264282...               0
# 29812  1.2.826.0.1.3680043.8.498.57132963920730995468...               0
# 29901  1.2.826.0.1.3680043.8.498.38513432620862771290...               0
#
#        ETT - Borderline  ETT - Normal  NGT - Abnormal  NGT - Borderline  \
# ...

# %%
no_one = raio_x_invasive_proce[(raio_x_invasive_proce == 1).sum(axis=1) < 1]
no_one.count()
# Out:
# StudyInstanceUID              24
# ETT - Abnormal                24
# ETT - Borderline              24
# ETT - Normal                  24
# NGT - Abnormal                24
# NGT - Borderline              24
# NGT - Incompletely Imaged     24
# NGT - Normal                  24
# CVC - Abnormal                24
# CVC - Borderline              24
# CVC - Normal                  24
# Swan Ganz Catheter Present    24
# PatientID                     24
# dtype: int64

# %%
one = raio_x_invasive_proce[(raio_x_invasive_proce == 1).sum(axis=1) < 2]
one.count()
# Out:
# StudyInstanceUID              18784
# ETT - Abnormal                18784
# ETT - Borderline              18784
# ETT - Normal                  18784
# NGT - Abnormal                18784
# NGT - Borderline              18784
# NGT - Incompletely Imaged     18784
# NGT - Normal                  18784
# CVC - Abnormal                18784
# CVC - Borderline              18784
# CVC - Normal                  18784
# Swan Ganz Catheter Present    18784
# PatientID                     18784
# dtype: int64

# %%
cvc_normal_abnormal_borderline = raio_x_invasive_proce.loc[(raio_x_invasive_proce['CVC - Borderline'] == 1)&(raio_x_invasive_proce['CVC - Normal'] == 1)&(raio_x_invasive_proce['CVC - Abnormal'] == 1)].count()['CVC - Abnormal']
cvc_normal_borderline = raio_x_invasive_proce.loc[(raio_x_invasive_proce['CVC - Borderline'] == 1)&(raio_x_invasive_proce['CVC - Normal'] == 1)&(raio_x_invasive_proce['CVC - Abnormal'] == 0)].count()['CVC - Abnormal']
cvc_normal_abnormal = raio_x_invasive_proce.loc[(raio_x_invasive_proce['CVC - Abnormal'] == 1)&(raio_x_invasive_proce['CVC - Normal'] == 1)&(raio_x_invasive_proce['CVC - Borderline'] == 0)].count()['CVC - Abnormal']
cvc_borderline_abnormal = raio_x_invasive_proce.loc[(raio_x_invasive_proce['CVC - Abnormal'] == 1)&(raio_x_invasive_proce['CVC - Borderline'] == 1)&(raio_x_invasive_proce['CVC - Normal'] == 0)].count()['CVC - Abnormal']
cvc_abnormal = raio_x_invasive_proce.loc[(raio_x_invasive_proce['CVC - Abnormal'] == 1)&(raio_x_invasive_proce['CVC - Borderline'] == 0)&(raio_x_invasive_proce['CVC - Normal'] == 0)].count()['CVC - Abnormal']
cvc_borderline = raio_x_invasive_proce.loc[(raio_x_invasive_proce['CVC - Abnormal'] == 0)&(raio_x_invasive_proce['CVC - Borderline'] == 1)&(raio_x_invasive_proce['CVC - Normal'] == 0)].count()['CVC - Abnormal']
cvc_normal = raio_x_invasive_proce.loc[(raio_x_invasive_proce['CVC - Abnormal'] == 0)&(raio_x_invasive_proce['CVC - Borderline'] == 0)&(raio_x_invasive_proce['CVC - Normal'] == 1)].count()['CVC - Abnormal']

cvc_multiples = ['Normal - Abnormal - Borderline', 'Normal - Borderline', 'Normal - Abnormal', 'Borderline - Abnormal']

cvc_multiples_values = [cvc_normal_abnormal_borderline, cvc_normal_borderline, cvc_normal_abnormal, cvc_borderline_abnormal]
print(cvc_multiples_values)
plt.figure(figsize=(10, 6))
plt.barh(cvc_multiples, cvc_multiples_values)

plt.xlabel('Frequencia')
plt.title('Gráfico do Grupo cvc')

plt.show()
# Out:
# [71, 2536, 658, 310]

# %%
cvc_only_one_value = [cvc_abnormal, cvc_borderline, cvc_normal]
cvc_only_one = ['Abnormal', 'Borderline', 'Normal']
print(cvc_only_one_value)
plt.figure(figsize=(10, 6))
plt.barh(cvc_only_one, cvc_only_one_value)

plt.xlabel('Frequencia')
plt.title('Gráfico do Grupo cvc')

plt.show()
# Out:
# [2156, 5543, 18059]

# %%
ngt_normal_abnormal_borderline = raio_x_invasive_proce.loc[(raio_x_invasive_proce['NGT - Borderline'] == 1)&(raio_x_invasive_proce['NGT - Normal'] == 1)&(raio_x_invasive_proce['NGT - Abnormal'] == 1)].count()['NGT - Abnormal']
ngt_normal_borderline = raio_x_invasive_proce.loc[(raio_x_invasive_proce['NGT - Borderline'] == 1)&(raio_x_invasive_proce['NGT - Normal'] == 1)&(raio_x_invasive_proce['NGT - Abnormal'] == 0)].count()['NGT - Abnormal']
ngt_normal_abnormal = raio_x_invasive_proce.loc[(raio_x_invasive_proce['NGT - Abnormal'] == 1)&(raio_x_invasive_proce['NGT - Normal'] == 1)&(raio_x_invasive_proce['NGT - Borderline'] == 0)].count()['NGT - Abnormal']
ngt_borderline_abnormal = raio_x_invasive_proce.loc[(raio_x_invasive_proce['NGT - Abnormal'] == 1)&(raio_x_invasive_proce['NGT - Borderline'] == 1)&(raio_x_invasive_proce['NGT - Normal'] == 0)].count()['NGT - Abnormal']
ngt_abnormal = raio_x_invasive_proce.loc[(raio_x_invasive_proce['NGT - Abnormal'] == 1)&(raio_x_invasive_proce['NGT - Borderline'] == 0)&(raio_x_invasive_proce['NGT - Normal'] == 0)&(raio_x_invasive_proce['NGT - Incompletely Imaged'] == 0)].count()['NGT - Abnormal']
ngt_borderline = raio_x_invasive_proce.loc[(raio_x_invasive_proce['NGT - Abnormal'] == 0)&(raio_x_invasive_proce['NGT - Borderline'] == 1)&(raio_x_invasive_proce['NGT - Normal'] == 0)&(raio_x_invasive_proce['NGT - Incompletely Imaged'] == 0)].count()['NGT - Abnormal']
ngt_normal = raio_x_invasive_proce.loc[(raio_x_invasive_proce['NGT - Abnormal'] == 0)&(raio_x_invasive_proce['NGT - Borderline'] == 0)&(raio_x_invasive_proce['NGT - Normal'] == 1)&(raio_x_invasive_proce['NGT - Incompletely Imaged'] == 0)].count()['NGT - Abnormal']

ngt_multiples = ['Normal - Abnormal - Borderline', 'Normal - Borderline', 'Normal - Abnormal', 'Borderline - Abnormal']

ngt_multiples_values = [ngt_normal_abnormal_borderline, ngt_normal_borderline, ngt_normal_abnormal, ngt_borderline_abnormal]
print(ngt_multiples_values)
plt.figure(figsize=(10, 6))
plt.barh(ngt_multiples, ngt_multiples_values)

plt.xlabel('Frequencia')
plt.title('Gráfico do Grupo NGT')

plt.show()
# Out:
# [0, 13, 9, 1]

# %%
ngt_inconclisive = raio_x_invasive_proce.loc[(raio_x_invasive_proce['NGT - Abnormal'] == 0)&(raio_x_invasive_proce['NGT - Borderline'] == 0)&(raio_x_invasive_proce['NGT - Incompletely Imaged'] == 1)&(raio_x_invasive_proce['NGT - Normal'] == 0)].count()['NGT - Abnormal']
ngt_inconclisive_normal = raio_x_invasive_proce.loc[(raio_x_invasive_proce['NGT - Abnormal'] == 0)&(raio_x_invasive_proce['NGT - Borderline'] == 0)&(raio_x_invasive_proce['NGT - Incompletely Imaged'] == 1)&(raio_x_invasive_proce['NGT - Normal'] == 1)].count()['NGT - Abnormal']
ngt_inconclisive_abnormal = raio_x_invasive_proce.loc[(raio_x_invasive_proce['NGT - Abnormal'] == 1)&(raio_x_invasive_proce['NGT - Borderline'] == 0)&(raio_x_invasive_proce['NGT - Incompletely Imaged'] == 1)&(raio_x_invasive_proce['NGT - Normal'] == 0)].count()['NGT - Abnormal']
ngt_inconclisive_borderline = raio_x_invasive_proce.loc[(raio_x_invasive_proce['NGT - Abnormal'] == 0)&(raio_x_invasive_proce['NGT - Borderline'] == 1)&(raio_x_invasive_proce['NGT - Incompletely Imaged'] == 1)&(raio_x_invasive_proce['NGT - Normal'] == 0)].count()['NGT - Abnormal']
ngt_inconclisive_normal_borderline = raio_x_invasive_proce.loc[(raio_x_invasive_proce['NGT - Abnormal'] == 0)&(raio_x_invasive_proce['NGT - Borderline'] == 1)&(raio_x_invasive_proce['NGT - Incompletely Imaged'] == 1)&(raio_x_invasive_proce['NGT - Normal'] == 1)].count()['NGT - Abnormal']
ngt_inconclisive_normal_abnormal = raio_x_invasive_proce.loc[(raio_x_invasive_proce['NGT - Abnormal'] == 1)&(raio_x_invasive_proce['NGT - Borderline'] == 0)&(raio_x_invasive_proce['NGT - Incompletely Imaged'] == 1)&(raio_x_invasive_proce['NGT - Normal'] == 1)].count()['NGT - Abnormal']
ngt_inconclisive_abnormal_borderline = raio_x_invasive_proce.loc[(raio_x_invasive_proce['NGT - Abnormal'] == 1)&(raio_x_invasive_proce['NGT - Borderline'] == 1)&(raio_x_invasive_proce['NGT - Incompletely Imaged'] == 1)&(raio_x_invasive_proce['NGT - Normal'] == 0)].count()['NGT - Abnormal']
ngt_inconclisive_abnormal_borderline_normal = raio_x_invasive_proce.loc[(raio_x_invasive_proce['NGT - Abnormal'] == 1)&(raio_x_invasive_proce['NGT - Borderline'] == 1)&(raio_x_invasive_proce['NGT - Incompletely Imaged'] == 1)&(raio_x_invasive_proce['NGT - Normal'] == 1)].count()['NGT - Abnormal']


ngt_multiples = [ 'Normal - Incompletely Imaged', 'Abnormal - Incompletely Imaged', 'Borderline - Incompletely Imaged']
ngt_multiples_values = [ngt_inconclisive_normal, ngt_inconclisive_abnormal, ngt_inconclisive_borderline]
print(ngt_multiples_values)
plt.figure(figsize=(10, 6))
plt.barh(ngt_multiples, ngt_multiples_values)

plt.xlabel('Frequencia')
plt.title('Gráfico do Grupo NGT')

plt.show()
# Out:
# [7, 10, 5]

# %%
ngt_multiples = ['Incompletely Imaged', 'Abnormal', 'Borderline', 'Normal']

ngt_multiples_values = [ngt_inconclisive, ngt_abnormal, ngt_borderline, ngt_normal]
print(ngt_multiples_values)
plt.figure(figsize=(10, 6))
plt.barh(ngt_multiples, ngt_multiples_values)

plt.xlabel('Frequencia')
plt.title('Gráfico do Grupo NGT')

plt.show()
# Out:
# [2726, 259, 510, 4768]

# %%
ngt_ett_cvc = raio_x_invasive_proce.loc[((raio_x_invasive_proce['NGT - Abnormal'] == 1)|(raio_x_invasive_proce['NGT - Borderline'] == 1)|(raio_x_invasive_proce['NGT - Incompletely Imaged'] == 1)|(raio_x_invasive_proce['NGT - Normal'] == 1))&((raio_x_invasive_proce['CVC - Abnormal'] == 1)|(raio_x_invasive_proce['CVC - Borderline'] == 1)|(raio_x_invasive_proce['CVC - Normal'] == 1))&((raio_x_invasive_proce['ETT - Abnormal'] == 1)|(raio_x_invasive_proce['ETT - Borderline'] == 1)|(raio_x_invasive_proce['ETT - Normal'] == 1))].count()['NGT - Abnormal']
ngt_ett = raio_x_invasive_proce.loc[((raio_x_invasive_proce['NGT - Abnormal'] == 1)|(raio_x_invasive_proce['NGT - Borderline'] == 1)|(raio_x_invasive_proce['NGT - Incompletely Imaged'] == 1)|(raio_x_invasive_proce['NGT - Normal'] == 1))&((raio_x_invasive_proce['ETT - Abnormal'] == 1)|(raio_x_invasive_proce['ETT - Borderline'] == 1)|(raio_x_invasive_proce['ETT - Normal'] == 1))&((raio_x_invasive_proce['CVC - Abnormal'] == 0)&(raio_x_invasive_proce['CVC - Borderline'] == 0)&(raio_x_invasive_proce['CVC - Normal'] == 0))].count()['NGT - Abnormal']
ngt_cvc = raio_x_invasive_proce.loc[((raio_x_invasive_proce['NGT - Abnormal'] == 1)|(raio_x_invasive_proce['NGT - Borderline'] == 1)|(raio_x_invasive_proce['NGT - Incompletely Imaged'] == 1)|(raio_x_invasive_proce['NGT - Normal'] == 1))&((raio_x_invasive_proce['CVC - Abnormal'] == 1)|(raio_x_invasive_proce['CVC - Borderline'] == 1)|(raio_x_invasive_proce['CVC - Normal'] == 1))&((raio_x_invasive_proce['ETT - Abnormal'] == 0)&(raio_x_invasive_proce['ETT - Borderline'] == 0)&(raio_x_invasive_proce['ETT - Normal'] == 0))].count()['NGT - Abnormal']
ett_cvc = raio_x_invasive_proce.loc[((raio_x_invasive_proce['CVC - Abnormal'] == 1)|(raio_x_invasive_proce['CVC - Borderline'] == 1)|(raio_x_invasive_proce['CVC - Normal'] == 1))&((raio_x_invasive_proce['ETT - Abnormal'] == 1)|(raio_x_invasive_proce['ETT - Borderline'] == 1)|(raio_x_invasive_proce['ETT - Normal'] == 1))&((raio_x_invasive_proce['NGT - Abnormal'] == 0)&(raio_x_invasive_proce['NGT - Borderline'] == 0)&(raio_x_invasive_proce['NGT - Incompletely Imaged'] == 0)&(raio_x_invasive_proce['NGT - Normal'] == 0))].count()['NGT - Abnormal']

ngt_ett_cvc_multiples = ['NGT - ETT - CVC', 'NGT - ETT', 'NGT - CVC', 'ETT - CVC' ]
ngt_ett_cvc_multiples_values = [ngt_ett_cvc, ngt_ett, ngt_cvc, ett_cvc]
print(ngt_ett_cvc_multiples_values)
plt.figure(figsize=(10, 6))
plt.barh(ngt_ett_cvc_multiples, ngt_ett_cvc_multiples_values)

plt.xlabel('Frequencia')
plt.title('Imagens com mais de um grupo')

plt.show()
# Out:
# [6288, 443, 1401, 1619]

# %%
ngt_ett_cvc_swan = raio_x_invasive_proce.loc[((raio_x_invasive_proce['NGT - Abnormal'] == 1)|(raio_x_invasive_proce['NGT - Borderline'] == 1)|(raio_x_invasive_proce['NGT - Incompletely Imaged'] == 1)|(raio_x_invasive_proce['NGT - Normal'] == 1))&((raio_x_invasive_proce['CVC - Abnormal'] == 1)|(raio_x_invasive_proce['CVC - Borderline'] == 1)|(raio_x_invasive_proce['CVC - Normal'] == 1))&((raio_x_invasive_proce['ETT - Abnormal'] == 1)|(raio_x_invasive_proce['ETT - Borderline'] == 1)|(raio_x_invasive_proce['ETT - Normal'] == 1))&(raio_x_invasive_proce['Swan Ganz Catheter Present'] == 1)].count()['NGT - Abnormal']
swan_only = raio_x_invasive_proce.loc[((raio_x_invasive_proce['NGT - Abnormal'] == 0)&(raio_x_invasive_proce['NGT - Borderline'] == 0)&(raio_x_invasive_proce['NGT - Incompletely Imaged'] == 0)&(raio_x_invasive_proce['NGT - Normal'] == 0))&((raio_x_invasive_proce['CVC - Abnormal'] == 0)&(raio_x_invasive_proce['CVC - Borderline'] == 0)&(raio_x_invasive_proce['CVC - Normal'] == 0))&((raio_x_invasive_proce['ETT - Abnormal'] == 0)&(raio_x_invasive_proce['ETT - Borderline'] == 0)&(raio_x_invasive_proce['ETT - Normal'] == 0))&(raio_x_invasive_proce['Swan Ganz Catheter Present'] == 1)].count()['NGT - Abnormal']
ngt_ett_swan = raio_x_invasive_proce.loc[((raio_x_invasive_proce['NGT - Abnormal'] == 1)|(raio_x_invasive_proce['NGT - Borderline'] == 1)|(raio_x_invasive_proce['NGT - Incompletely Imaged'] == 1)|(raio_x_invasive_proce['NGT - Normal'] == 1))&((raio_x_invasive_proce['CVC - Abnormal'] == 0)&(raio_x_invasive_proce['CVC - Borderline'] == 0)&(raio_x_invasive_proce['CVC - Normal'] == 0))&((raio_x_invasive_proce['ETT - Abnormal'] == 1)|(raio_x_invasive_proce['ETT - Borderline'] == 1)|(raio_x_invasive_proce['ETT - Normal'] == 1))&(raio_x_invasive_proce['Swan Ganz Catheter Present'] == 1)].count()['NGT - Abnormal']
cvc_swan = raio_x_invasive_proce.loc[((raio_x_invasive_proce['NGT - Abnormal'] == 0)&(raio_x_invasive_proce['NGT - Borderline'] == 0)&(raio_x_invasive_proce['NGT - Incompletely Imaged'] == 0)&(raio_x_invasive_proce['NGT - Normal'] == 0))&((raio_x_invasive_proce['CVC - Abnormal'] == 1)|(raio_x_invasive_proce['CVC - Borderline'] == 1)|(raio_x_invasive_proce['CVC - Normal'] == 1))&((raio_x_invasive_proce['ETT - Abnormal'] == 0)&(raio_x_invasive_proce['ETT - Borderline'] == 0)&(raio_x_invasive_proce['ETT - Normal'] == 0))&(raio_x_invasive_proce['Swan Ganz Catheter Present'] == 1)].count()['NGT - Abnormal']

ngt_ett_cvc_swan_multiples = ['NGT - ETT - CVC - Swan Ganz', 'NGT - ETT - Swan Ganz', 'CVC - Swan Ganz', 'Swan Ganz']
ngt_ett_cvc_swan_multiples_values = [ngt_ett_cvc_swan, ngt_ett_swan, cvc_swan, swan_only]
print(ngt_ett_cvc_swan_multiples_values)
plt.figure(figsize=(10, 6))
plt.barh(ngt_ett_cvc_swan_multiples, ngt_ett_cvc_swan_multiples_values)

plt.xlabel('Frequencia')
plt.title('Gráfico Swan Ganz')

plt.show()
# Out:
# [613, 10, 131, 0]

# %%
cvc_sum = len(raio_x_invasive_proce.loc[(raio_x_invasive_proce['CVC - Abnormal'] == 1)|(raio_x_invasive_proce['CVC - Borderline'] == 1)|(raio_x_invasive_proce['CVC - Normal'] == 1)])
not_cvc = raio_x_invasive_proce.loc[(raio_x_invasive_proce['CVC - Abnormal'] == 0)&(raio_x_invasive_proce['CVC - Borderline'] == 0)&(raio_x_invasive_proce['CVC - Normal'] == 0)].count()['CVC - Abnormal']

values_Cvc = [cvc_sum, not_cvc]
labels_Cvc = ['Contem CVC', 'Sem CVC']

plt.figure(figsize=(10, 6))
plt.barh(labels_Cvc, values_Cvc)

plt.xlabel('Imagens')
plt.title('Imagens com CVC')

for i, v in enumerate(values_Cvc):
    plt.text(v, i, f'{v}', va='center')

plt.show()

# %%
ngt_sum = len(raio_x_invasive_proce.loc[(raio_x_invasive_proce['NGT - Abnormal'] == 1)|(raio_x_invasive_proce['NGT - Borderline'] == 1)|(raio_x_invasive_proce['NGT - Normal'] == 1)|(raio_x_invasive_proce['NGT - Incompletely Imaged'] == 1)])
not_ngt = raio_x_invasive_proce.loc[(raio_x_invasive_proce['NGT - Abnormal'] == 0)&(raio_x_invasive_proce['NGT - Borderline'] == 0)&(raio_x_invasive_proce['NGT - Normal'] == 0)&(raio_x_invasive_proce['NGT - Incompletely Imaged'] == 0)].count()['NGT - Abnormal']

values_Ngt = [ngt_sum, not_ngt]
labels_Ngt = ['Contem NGT', 'Sem NGT']

plt.figure(figsize=(10, 6))
plt.barh(labels_Ngt, values_Ngt)

plt.xlabel('Imagens')
plt.title('Imagens com NGT')

for i, v in enumerate(values_Ngt):
    plt.text(v, i, f'{v}', va='center')

plt.show()

# %%
ett_sum = len(raio_x_invasive_proce.loc[(raio_x_invasive_proce['ETT - Abnormal'] == 1)|(raio_x_invasive_proce['ETT - Borderline'] == 1)|(raio_x_invasive_proce['ETT - Normal'] == 1)])
not_ett = raio_x_invasive_proce.loc[(raio_x_invasive_proce['ETT - Abnormal'] == 0)&(raio_x_invasive_proce['ETT - Borderline'] == 0)&(raio_x_invasive_proce['ETT - Normal'] == 0)].count()['ETT - Abnormal']

values_Ett = [ett_sum, not_ett]
labels_Ett = ['Contem ETT', 'Sem ETT']

plt.figure(figsize=(10, 6))
plt.barh(labels_Ett, values_Ett)

plt.xlabel('Imagens')
plt.title('Imagens com ETT')

for i, v in enumerate(values_Ett):
    plt.text(v, i, f'{v}', va='center')

plt.show()

# %%
swan_sum = raio_x_invasive_proce.where(raio_x_invasive_proce['Swan Ganz Catheter Present'] == 1).count()['Swan Ganz Catheter Present']
not_swan = raio_x_invasive_proce.where(raio_x_invasive_proce['Swan Ganz Catheter Present'] == 0).count()['Swan Ganz Catheter Present']

values_Swan = [swan_sum, not_swan]
labels_Swan = ['Contem Swan Ganz Catheter', 'Sem Swan Ganz Catheter']

plt.figure(figsize=(10, 6))
plt.barh(labels_Swan, values_Swan)

plt.xlabel('Imagens')
plt.title('Imagens com Swan Ganz Catheter')

for i, v in enumerate(values_Swan):
    plt.text(v, i, f'{v}', va='center')

plt.show()
